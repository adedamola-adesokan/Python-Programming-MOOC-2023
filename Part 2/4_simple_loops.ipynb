# %% [markdown]
# Let's create a program along the lines of the example above. This program should print out the message "hi" and then ask "Shall we continue?" until the user inputs "no". Then the program should print out "okay then" and finish.

# %%
# Write your solution here

while True:
    print("hi")
    input_ = input("Shall we continue? ")
    if input_ == "no":
        break
        
print("okay then")
# Out:
# hi
# hi
# hi
# hi
# hi
# okay then

# %% [markdown]
# Please write a program which asks the user for integer numbers.
#
# If the number is below zero, the program should print out the message "Invalid number".
#
# If the number is above zero, the program should print out the square root of the number using the Python sqrt function.
#
# In either case, the program should then ask for another number.
#
# If the user inputs the number zero, the program should stop asking for numbers and exit the loop.

# %%
from math import sqrt
# Write your solution here

while True:

    number = int(input("Please type in a number: "))
    if number < 0:
        print("Invalid number")
    elif number > 0:
        print(f"{sqrt(number)}")
    else:
        break

print("Exiting...")
# Out:
# 6.708203932499369
# 6.708203932499369
# 7.483314773547883
# Invalid number
# Exiting...

# %% [markdown]
# This program should print out a countdown. The code is as follows:

# %%
number = 5
print("Countdown!")
while True:
  print(number)
  number = number - 1
  if number < 1:
    break

print("Now!")
# Out:
# Countdown!
# 5
# 4
# 3
# 2
# 1
# Now!

# %% [markdown]
# Please write a program which asks the user for a password. The program should then ask the user to type in the password again. If the user types in something else than the first password, the program should keep on asking until the user types the first password again correctly.

# %%
# Write your solution here

password_1 = input("Password: ")

while True:
    password_2 = input("Repeat password: ")

    if password_1 == password_2:
        break
    else:
        print("They do not match!")

print("User account created!")
# Out:
# They do not match!
# User account created!

# %% [markdown]
# Please write a program which keeps asking the user for a PIN code until they type in the correct one, which is 4321. The program should then print out the number of times the user tried different codes.

# %%
# Write your solution here

attempts = 0

while True:
    pin = int(input("PIN: "))
    attempts += 1

    if pin == 4321:
        pin_correct = True
        break
    else:
        print("Wrong")


if pin_correct and attempts == 1:
    print("Correct! It only took you one single attempt!")
else:
    print(f"Correct! It took you {attempts} attempts")
# Out:
# Wrong
# Wrong
# Wrong
# Wrong
# Wrong
# Wrong
# Correct! It took you 7 attempts

# %% [markdown]
# Please write a program which asks the user for a year, and prints out the next leap year.

# %%
# Write your solution here
year = int(input("Year:"))
next_leap_year = year + 1
while True:
    if next_leap_year % 4 == 0 and next_leap_year % 100 == 0:
        if next_leap_year % 400 == 0:
            print(f"The next leap year after {year} is {next_leap_year}") 
            break
        else:
            next_leap_year = next_leap_year + 4
            print(f"The next leap year after {year} is {next_leap_year}")
            break
    elif next_leap_year % 4 == 0:
        print(f"The next leap year after {year} is {next_leap_year}")
        break
    else:
        next_leap_year += 1
# Out:
# The next leap year after 1987 is 1988

# %% [markdown]
# Please write a program which keeps asking the user for words. If the user types in end, the program should print out the story the words formed, and finish.

# %%
# Write your solution here

sentence = ""
last_word = ""
while True:
    word = input("Please type in a word: ")
    
    if last_word == word or word == "end":
        break
    else:
        sentence+= word + " "
        last_word = word
    

print(sentence)

# %% [markdown]
# Please write a program which asks the user for integer numbers. The program should keep asking for numbers until the user types in zero.

# %%
# Write your solution here
print("Please type in integer numbers. Type in 0 to finish.")
numbers = ""
counter = 0
total = 0
positive = 0
negative = 0
while True:
    number = int(input("Number: "))

    if number == 0:
        break
    if number > 0:
        positive += 1
    else:
        negative += 1
    counter += 1
    total += number
    numbers = numbers + str(number) + ","

print("... the program asks for numbers")
print(f"Numbers typed in {counter}")
print(f"The sum of the numbers is {total}")
print(f"The mean of the numbers is {total/counter}")
print(f"Positive numbers {positive}")
print(f"Negative numbers {negative}")
# Out:
# Please type in integer numbers. Type in 0 to finish.
# ... the program asks for numbers
# Numbers typed in 8
# The sum of the numbers is 108
# The mean of the numbers is 13.5
# Positive numbers 8
# Negative numbers 0
